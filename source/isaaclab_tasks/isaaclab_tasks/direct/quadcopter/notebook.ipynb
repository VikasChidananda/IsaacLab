# %%
import torch

from trajectory_generator import TrajectoryGenerator, TrajectoryManager

# %%
traj = TrajectoryGenerator

t = torch.linspace(0, 10, steps=100)
traj.circle(radius=2.0, freq=0.5, z_height=1.0, t=t )
# Out:
# array([[ 2.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#        [ 1.9001422e+00,  6.2406689e-01,  1.0000000e+00],
#        [ 1.6105405e+00,  1.1858159e+00,  1.0000000e+00],
#        [ 1.1601137e+00,  1.6291519e+00,  1.0000000e+00],
#        [ 5.9384072e-01,  1.9098045e+00,  1.0000000e+00],
#        [-3.1731792e-02,  1.9997482e+00,  1.0000000e+00],
#        [-6.5413606e-01,  1.8900015e+00,  1.0000000e+00],
#        [-1.2112195e+00,  1.5915235e+00,  1.0000000e+00],
#        [-1.6473532e+00,  1.1341197e+00,  1.0000000e+00],
#        [-1.9189860e+00,  5.6346518e-01,  1.0000000e+00],
#        [-1.9989930e+00, -6.3455589e-02,  1.0000000e+00],
#        [-1.8793854e+00, -6.8403989e-01,  1.0000000e+00],
#        [-1.5721060e+00, -1.2363182e+00,  1.0000000e+00],
#        [-1.1078401e+00, -1.6651398e+00,  1.0000000e+00],
#        [-5.3294718e-01, -1.9276844e+00,  1.0000000e+00],
#        [ 9.5163658e-02, -1.9977347e+00,  1.0000000e+00],
# ...
